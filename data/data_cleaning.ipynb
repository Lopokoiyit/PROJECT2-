# %%
import pandas as pd

# %%
vic_production_df = pd.read_csv("csv/vic_production.csv")
vic_production_df["State"] = "VIC"
vic_production_df = vic_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)")            
vic_production_df
# Out:
#                 Fuel Source      Renewable State Financial Year  \
# 0                Black coal  Non-Renewable   VIC        2008-09
# 1                Brown coal  Non-Renewable   VIC        2008-09
# 2               Natural gas  Non-Renewable   VIC        2008-09
# 3              Oil products  Non-Renewable   VIC        2008-09
# 4                     Other  Non-Renewable   VIC        2008-09
# ..                      ...            ...   ...            ...
# 151                    Wind      Renewable   VIC        2020-21
# 152                   Hydro      Renewable   VIC        2020-21
# 153    Large-scale solar PV      Renewable   VIC        2020-21
# 154    Small-scale solar PV      Renewable   VIC        2020-21
# 155              Geothermal      Renewable   VIC        2020-21
#
#     Energy production (GWh)
# 0                       NaN
# 1                  52,094.0
# 2                   1,451.9
# 3                      20.4
# 4                      61.1
# ..                      ...
# 151                 7,080.6
# 152                 2,852.0
# 153                 1,455.5
# 154                 3,176.4
# 155                     NaN
#
# [156 rows x 5 columns]

# %%
vic_consumption_df = pd.read_csv("csv/vic_consumption.csv")
vic_consumption_df["State"] = "VIC"
vic_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million) Energy consumption (PJ)  \
# 0        2008-09  5,371,934         364,430                 1,428.4
# 1        2009-10  5,461,101         367,948                 1,433.5
# 2        2010-11  5,537,817         378,616                 1,455.7
# 3        2011-12  5,651,091         387,684                 1,464.4
# 4        2012-13  5,772,669         391,361                 1,429.3
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      265.9                         3,919.4
# 1                                      262.5                         3,895.8
# 2                                      262.9                         3,844.8
# 3                                      259.1                         3,777.3
# 4                                      247.6                         3,652.2
#
#    Energy productivity ($ million/PJ) State
# 0                               255.1   VIC
# 1                               256.7   VIC
# 2                               260.1   VIC
# 3                               264.7   VIC
# 4                               273.8   VIC

# %%
vic_industry_consumption_df = pd.read_csv("csv/vic_industry_consumption.csv")
vic_industry_consumption_df["State"] = "VIC"
vic_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09              14.2         28.0               206.9
# 1        2009-10              15.6         24.5               213.8
# 2        2010-11              15.6         24.9               237.1
# 3        2011-12              15.7         27.0               229.6
# 4        2012-13              15.4         27.0               239.6
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                        560.4               10.0           339.6
# 1                        548.2                9.7           345.5
# 2                        534.2                9.8           352.1
# 3                        557.0               10.1           345.7
# 4                        508.1                9.9           352.8
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   2.5                          82.4             159.1
# 1                   3.1                          85.8             160.8
# 2                   2.3                          89.8             162.9
# 3                   3.4                          88.3             161.9
# 4                   2.8                          89.8             164.3
#
#    Other (PJ) State
# 0        25.3   VIC
# 1        26.6   VIC
# 2        27.2   VIC
# 3        25.8   VIC
# 4        19.5   VIC

# %%
nsw_production_df = pd.read_csv("csv/nsw_production.csv")
nsw_production_df["State"] = "NSW"
nsw_production_df = nsw_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)")  
nsw_production_df.head()
# Out:
#       Fuel Source      Renewable State Financial Year Energy production (GWh)
# 0      Black coal  Non-Renewable   NSW        2008-09                67,650.3
# 1      Brown coal  Non-Renewable   NSW        2008-09                     NaN
# 2     Natural gas  Non-Renewable   NSW        2008-09                 2,445.1
# 3    Oil products  Non-Renewable   NSW        2008-09                    24.7
# 4         Other a  Non-Renewable   NSW        2008-09                   336.6

# %%
nsw_consumption_df = pd.read_csv("csv/nsw_consumption.csv")
nsw_consumption_df["State"] = "NSW"
nsw_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million) Energy consumption (PJ)  \
# 0        2008-09  7,408,540         523,607                 1,593.5
# 1        2009-10  7,506,058         532,452                 1,645.3
# 2        2010-11  7,586,514         543,726                 1,668.0
# 3        2011-12  7,680,783         557,491                 1,621.3
# 4        2012-13  7,787,289         570,117                 1,568.4
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      215.1                         3,043.4
# 1                                      219.2                         3,090.0
# 2                                      219.9                         3,067.8
# 3                                      211.1                         2,908.2
# 4                                      201.4                         2,751.1
#
#    Energy productivity ($ million/PJ) State
# 0                               328.6   NSW
# 1                               323.6   NSW
# 2                               326.0   NSW
# 3                               343.9   NSW
# 4                               363.5   NSW

# %%
nsw_industry_consumption_df = pd.read_csv("csv/nsw_industry_consumption.csv")
nsw_industry_consumption_df["State"] = "NSW"
nsw_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09              28.4         35.5               308.1
# 1        2009-10              28.6         41.7               362.4
# 2        2010-11              28.9         46.3               400.9
# 3        2011-12              29.4         52.8               355.7
# 4        2012-13              29.2         58.6               309.7
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                        504.0                7.8           479.2
# 1                        468.7                9.0           498.5
# 2                        438.2                8.7           504.9
# 3                        434.9                8.0           506.6
# 4                        407.1                8.6           513.2
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   5.5                          76.7             130.8
# 1                   5.0                          79.2             134.0
# 2                   4.6                          82.0             137.0
# 3                   4.5                          80.3             135.5
# 4                   3.3                          83.4             135.3
#
#    Other (PJ) State
# 0        17.7   NSW
# 1        18.1   NSW
# 2        16.6   NSW
# 3        13.6   NSW
# 4        20.2   NSW

# %%
qld_production_df=pd.read_csv("csv/qld_production.csv")
qld_production_df["State"] = "QLD"
qld_production_df = qld_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)") 
qld_production_df.head()
# Out:
#       Fuel Source  Renewable State Financial Year Energy production (GWh)
# 0      Black coal  Renewable   QLD        2008-09                50,882.2
# 1      Brown coal  Renewable   QLD        2008-09                     NaN
# 2     Natural gas  Renewable   QLD        2008-09                 9,257.2
# 3    Oil products  Renewable   QLD        2008-09                   711.4
# 4           Other  Renewable   QLD        2008-09                   691.8

# %%
qld_consumption_df = pd.read_csv("csv/qld_consumption.csv")
qld_consumption_df["State"] = "QLD"
qld_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million) Energy consumption (PJ)  \
# 0        2008-09  4,328,771         286,209                 1,345.7
# 1        2009-10  4,404,744         292,181                 1,294.4
# 2        2010-11  4,476,778         294,831                 1,249.6
# 3        2011-12  4,568,687         312,040                 1,314.8
# 4        2012-13  4,652,824         320,969                 1,334.8
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      310.9                         4,701.9
# 1                                      293.9                         4,430.1
# 2                                      279.1                         4,238.4
# 3                                      287.8                         4,213.6
# 4                                      286.9                         4,158.6
#
#    Energy productivity ($ million/PJ) State
# 0                               212.7   QLD
# 1                               225.7   QLD
# 2                               235.9   QLD
# 3                               237.3   QLD
# 4                               240.5   QLD

# %%
qld_industry_consumption_df = pd.read_csv("csv/qld_industry_consumption.csv")
qld_industry_consumption_df["State"] = "QLD"
qld_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09              22.5         80.3               279.3
# 1        2009-10              22.6         86.5               302.4
# 2        2010-11              22.9         91.0               301.7
# 3        2011-12              23.3        104.4               303.5
# 4        2012-13              24.8        118.2               324.1
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                        497.2                8.1           321.5
# 1                        410.5                7.4           326.0
# 2                        360.2                7.2           329.6
# 3                        397.2                6.7           343.7
# 4                        374.9                6.3           346.8
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   1.5                          55.7              57.1
# 1                   1.1                          55.5              58.4
# 2                   1.1                          56.4              60.1
# 3                   1.2                          54.7              59.9
# 4                   1.1                          58.5              60.8
#
#    Other (PJ) State
# 0        22.6   QLD
# 1        24.0   QLD
# 2        19.4   QLD
# 3        20.3   QLD
# 4        19.3   QLD

# %%
wa_production_df=pd.read_csv("csv/wa_production.csv")
wa_production_df["State"] = "WA"
wa_production_df = wa_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)")  
wa_production_df.head()
# Out:
#       Fuel Source      Renewable State Financial Year Energy production (GWh)
# 0      Black coal  Non-Renewable    WA        2008-09                 8,738.0
# 1      Brown coal  Non-Renewable    WA        2008-09                     NaN
# 2     Natural gas  Non-Renewable    WA        2008-09                14,556.1
# 3    Oil products  Non-Renewable    WA        2008-09                 1,464.4
# 4           Other  Non-Renewable    WA        2008-09                 2,153.0

# %%
wa_consumption_df = pd.read_csv("csv/wa_consumption.csv")
wa_consumption_df["State"] = "WA"
wa_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million) Energy consumption (PJ)  \
# 0        2008-09  2,240,250         216,002                   917.4
# 1        2009-10  2,290,845         228,873                   905.9
# 2        2010-11  2,353,409         239,627                   980.4
# 3        2011-12  2,425,507         259,517                   982.2
# 4        2012-13  2,486,944         275,222                 1,019.5
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      409.5                         4,247.2
# 1                                      395.4                         3,958.0
# 2                                      416.6                         4,091.3
# 3                                      405.0                         3,784.9
# 4                                      409.9                         3,704.3
#
#    Energy productivity ($ million/PJ) State
# 0                               235.5    WA
# 1                               252.7    WA
# 2                               244.4    WA
# 3                               264.2    WA
# 4                               270.0    WA

# %%
wa_industry_consumption_df = pd.read_csv("csv/wa_industry_consumption.csv")
wa_industry_consumption_df["State"] = "WA"
wa_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09              15.6        169.2               243.6
# 1        2009-10              16.8        169.0               244.6
# 2        2010-11              17.6        189.3               259.8
# 3        2011-12              18.4        207.3               225.9
# 4        2012-13              18.1        234.0               234.9
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                        232.1                3.7           179.3
# 1                        219.4                3.4           180.0
# 2                        236.5                3.8           193.3
# 3                        233.0                3.8           210.5
# 4                        228.9                3.8           217.4
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   2.2                          28.3              36.6
# 1                   2.3                          27.4              36.7
# 2                   3.5                          29.5              40.4
# 3                   4.7                          30.4              42.0
# 4                   3.2                          31.0              41.0
#
#    Other (PJ) State
# 0         6.9    WA
# 1         6.4    WA
# 2         6.6    WA
# 3         6.2    WA
# 4         7.2    WA

# %%
tas_production_df=pd.read_csv("csv/tas_production.csv")
tas_production_df["State"] = "TAS"
tas_production_df = tas_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)")  
tas_production_df.head()
# Out:
#       Fuel Source      Renewable State Financial Year Energy production (GWh)
# 0      Black coal  Non-Renewable   TAS        2008-09                     NaN
# 1      Brown coal  Non-Renewable   TAS        2008-09                     NaN
# 2     Natural gas  Non-Renewable   TAS        2008-09                   705.3
# 3    Oil products  Non-Renewable   TAS        2008-09                    64.5
# 4           Other  Non-Renewable   TAS        2008-09                     NaN

# %%
tas_consumption_df = pd.read_csv("csv/tas_consumption.csv")
tas_consumption_df["State"] = "TAS"
tas_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million)  Energy consumption (PJ)  \
# 0        2008-09    504,353          27,684                    113.8
# 1        2009-10    508,847          27,905                    113.7
# 2        2010-11    511,483          28,590                    113.8
# 3        2011-12    511,724          29,156                    107.0
# 4        2012-13    512,231          28,999                    112.3
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      225.6                         4,110.5
# 1                                      223.5                         4,076.1
# 2                                      222.5                         3,981.3
# 3                                      209.0                         3,668.9
# 4                                      219.3                         3,873.3
#
#    Energy productivity ($ million/PJ) State
# 0                               243.3   TAS
# 1                               245.3   TAS
# 2                               251.2   TAS
# 3                               272.6   TAS
# 4                               258.2   TAS

# %%
tas_industry_consumption_df = pd.read_csv("csv/tas_industry_consumption.csv")
tas_industry_consumption_df["State"] = "TAS"
tas_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09               3.7          3.1                45.2
# 1        2009-10               3.7          3.0                44.1
# 2        2010-11               3.0          3.2                44.1
# 3        2011-12               3.0          3.6                40.8
# 4        2012-13               3.5          3.4                45.3
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                          7.3                0.5            29.7
# 1                          8.5                0.5            29.9
# 2                         10.8                0.5            27.9
# 3                          9.7                0.4            25.7
# 4                         10.4                0.3            25.6
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   0.1                           8.2              14.7
# 1                   0.1                           8.2              14.9
# 2                   0.2                           8.6              14.5
# 3                   0.2                           8.2              14.5
# 4                   0.1                           8.4              14.5
#
#    Other (PJ) State
# 0         1.2   TAS
# 1         0.9   TAS
# 2         0.9   TAS
# 3         0.9   TAS
# 4         0.9   TAS

# %%
sa_production_df=pd.read_csv("csv/sa_production.csv")
sa_production_df["State"] = "SA"
sa_production_df = sa_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)")  
sa_production_df.head()
# Out:
#       Fuel Source      Renewable State Financial Year Energy production (GWh)
# 0      Black coal  Non-Renewable    SA        2008-09                     NaN
# 1      Brown coal  Non-Renewable    SA        2008-09                 4,887.4
# 2     Natural gas  Non-Renewable    SA        2008-09                 7,371.4
# 3    Oil products  Non-Renewable    SA        2008-09                    63.2
# 4           Other  Non-Renewable    SA        2008-09                   337.4

# %%
sa_consumption_df = pd.read_csv("csv/sa_consumption.csv")
sa_consumption_df["State"] = "SA"
sa_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million)  Energy consumption (PJ)  \
# 0        2008-09  1,608,902          98,259                    357.2
# 1        2009-10  1,627,322         100,302                    343.7
# 2        2010-11  1,639,614         102,564                    342.8
# 3        2011-12  1,656,725         103,611                    307.7
# 4        2012-13  1,671,488         104,385                    356.3
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      222.0                         3,635.5
# 1                                      211.2                         3,426.9
# 2                                      209.1                         3,342.4
# 3                                      185.7                         2,969.4
# 4                                      213.2                         3,413.1
#
#    Energy productivity ($ million/PJ) State
# 0                               275.1    SA
# 1                               291.8    SA
# 2                               299.2    SA
# 3                               336.8    SA
# 4                               293.0    SA

# %%
sa_industry_consumption_df = pd.read_csv("csv/sa_industry_consumption.csv")
sa_industry_consumption_df["State"] = "SA"
sa_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09               8.2         28.3                66.9
# 1        2009-10               7.7         27.5                69.7
# 2        2010-11               7.0         29.4                63.0
# 3        2011-12               7.2         31.5                35.2
# 4        2012-13               7.1         33.7                88.2
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                         91.7                2.2            96.0
# 1                         76.1                2.3            96.7
# 2                         80.3                2.3            97.8
# 3                         71.7                2.2            97.0
# 4                         62.5                2.0           100.0
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   1.8                          20.4              35.9
# 1                   1.3                          20.7              36.1
# 2                   1.3                          18.7              36.5
# 3                   1.5                          18.1              37.3
# 4                   2.5                          18.7              37.3
#
#    Other (PJ) State
# 0         5.8    SA
# 1         5.7    SA
# 2         6.5    SA
# 3         6.1    SA
# 4         4.3    SA

# %%
nt_production_df=pd.read_csv("csv/nt_production.csv")
nt_production_df["State"] = "NT"
nt_production_df = nt_production_df.melt(id_vars=["Fuel Source", "Renewable", "State"], var_name ="Financial Year", value_name="Energy production (GWh)")  
nt_production_df.head()
# Out:
#       Fuel Source      Renewable State Financial Year Energy production (GWh)
# 0      Black coal  Non-Renewable    NT        2008-09                     NaN
# 1      Brown coal  Non-Renewable    NT        2008-09                     NaN
# 2     Natural gas  Non-Renewable    NT        2008-09                 1,873.4
# 3    Oil products  Non-Renewable    NT        2008-09                 1,039.3
# 4           Other  Non-Renewable    NT        2008-09                     NaN

# %%
nt_consumption_df = pd.read_csv("csv/nt_consumption.csv")
nt_consumption_df["State"] = "NT"
nt_consumption_df.head()
# Out:
#   Financial Year Population GSP ($ Million)  Energy consumption (PJ)  \
# 0        2008-09    226,027          20,356                     95.0
# 1        2009-10    229,778          20,250                     94.2
# 2        2010-11    231,292          20,852                     99.8
# 3        2011-12    235,915          21,698                     98.2
# 4        2012-13    241,722          23,197                    100.2
#
#    Energy consumption per capita (GJ/Person) Energy intensity (GJ/$ million)  \
# 0                                      420.5                         4,669.1
# 1                                      409.8                         4,650.6
# 2                                      431.4                         4,785.4
# 3                                      416.2                         4,525.5
# 4                                      414.3                         4,317.6
#
#    Energy productivity ($ million/PJ) State
# 0                               214.2    NT
# 1                               215.0    NT
# 2                               209.0    NT
# 3                               221.0    NT
# 4                               231.6    NT

# %%
nt_industry_consumption_df = pd.read_csv("csv/nt_industry_consumption.csv")
nt_industry_consumption_df["State"] = "NT"
nt_industry_consumption_df.head()
# Out:
#   Financial Year  Agriculture (PJ)  Mining (PJ)  Manufacturing (PJ)  \
# 0        2008-09               1.3         25.1                21.5
# 1        2009-10               1.3         20.0                23.0
# 2        2010-11               1.3         23.4                24.0
# 3        2011-12               1.3         21.5                24.2
# 4        2012-13               1.3         26.0                23.2
#
#    Electricity generation (PJ)  Construction (PJ)  Transport (PJ)  \
# 0                         21.3                0.3            14.8
# 1                         23.8                0.3            14.3
# 2                         22.4                0.4            18.8
# 3                         22.9                0.4            18.4
# 4                         22.1                0.5            18.2
#
#    Water and waste (PJ)  Commercial and services (PJ)  Residential (PJ)  \
# 0                   0.0                           7.0               3.2
# 1                   0.2                           7.6               3.3
# 2                   0.1                           6.2               2.7
# 3                   0.1                           6.6               2.3
# 4                   0.0                           6.3               2.1
#
#    Other (PJ) State
# 0         0.7    NT
# 1         0.4    NT
# 2         0.6    NT
# 3         0.4    NT
# 4         0.5    NT
